# %%
# importing required libraries

import pandas as pd
import pyodbc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import pyodbc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4870f38d7e57> in <module>()
#       2
#       3 import pandas as pd
# ----> 4 import pyodbc
#       5 import pandas as pd
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'pyodbc'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # 1. PULLING DATA FROM SQL

# %%
import mysql.connector as mc

# connection creation
conn = mc.connect(host='localhost', user='root', passwd='Raju.b,443')
print(conn)

#create cursor object

cur = conn.cursor()
print(cur)

cur.execute('show databases')

for i in cur:
    print(i)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001F644BEA610>
# CMySQLCursor: (Nothing executed yet)
# ('employee',)
# ('employee_performance',)
# ('information_schema',)
# ('mysql',)
# ('perfor',)
# ('performance',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('wfh_emp',)
# ('world',)

# %%
query = "Select * from employee_performance.employ_mod_recent"
df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      ï»¿Employee_ID  Age  Gender Marital_status   Education  \
# 0            EM1000   47    Male         single  Vocational
# 1            EM1001   34  Female       divorced  Vocational
# 2            EM1002   38  Female        married  Vocational
# 3            EM1003   49  Female        married      Master
# 4            EM1004   38    Male        married  Vocational
# ...             ...  ...     ...            ...         ...
# 5095         EM6095   70    Male         single      Master
# 5096         EM6096   68  Female       divorced  Vocational
# 5097         EM6097   69  Female        married      Master
# 5098         EM6098   45    Male        married  Vocational
# 5099         EM6099   60    Male       divorced    Bachelor
#
#      EnvironmentSatisfaction JobInvolvement  Job_level Job_satisfaction  \
# 0                     medium      very high          5           Medium
# 1                  very high      very high          2              low
# 2                  very high           high          2             high
# 3                       high            low          4             high
# 4                        low           high          1           Medium
# ...                      ...            ...        ...              ...
# 5095                    high      very high          3              low
# 5096                    high           high          4           Medium
# 5097                     low      very high          4             high
# 5098                    high           high          1        very high
# 5099                    high      very high          1              low
#
#       Annual_income  ... ProjectCompletion WorkingFromHome  \
# 0                14  ...                 9              No
# 1                13  ...                14             Yes
# 2                 9  ...                12              No
# 3                 9  ...                12             Yes
# 4                22  ...                 9             Yes
# ...             ...  ...               ...             ...
# 5095             11  ...                 9             Yes
# 5096             11  ...                14             Yes
# 5097             23  ...                 9             Yes
# 5098             19  ...                14             Yes
# 5099             20  ...                 5              No
#
#       Psycho_social_indicators  Over_time Attendance PercentSalaryHike  \
# 0                   Inadequate         No       good                 8
# 1                   Inadequate         No       good                 3
# 2                    excellent        Yes       good                 3
# 3                    excellent        Yes       good                13
# 4                   Inadequate        Yes       good                 7
# ...                        ...        ...        ...               ...
# 5095                 Very_good        Yes       good                16
# 5096                Inadequate         No       good                 7
# 5097              satisfactory         No       poor                 9
# 5098              satisfactory         No       good                 3
# 5099                 Very_good         No       poor                 7
#
#      NetConnectivity Department        Position Performancerating
# 0               Poor         RD       Scientist           average
# 1               good    Finance  Budget Analyst              good
# 2               Poor         IT     Team leader              good
# 3               good    Finance  Budget Analyst              good
# 4               good         RD       Scientist           average
# ...              ...        ...             ...               ...
# 5095            good      Sales       Executive              poor
# 5096            good        HRM              HR              poor
# 5097            Poor         RD       Scientist              poor
# 5098            good    Finance  Budget Analyst              poor
# 5099            good         IT     Team leader           average
#
# [5100 rows x 28 columns]

# %%
#To view first five rows in the dataset
df.head()
# Out:
#   ï»¿Employee_ID  Age  Gender Marital_status   Education  \
# 0         EM1000   47    Male         single  Vocational
# 1         EM1001   34  Female       divorced  Vocational
# 2         EM1002   38  Female        married  Vocational
# 3         EM1003   49  Female        married      Master
# 4         EM1004   38    Male        married  Vocational
#
#   EnvironmentSatisfaction JobInvolvement  Job_level Job_satisfaction  \
# 0                  medium      very high          5           Medium
# 1               very high      very high          2              low
# 2               very high           high          2             high
# 3                    high            low          4             high
# 4                     low           high          1           Medium
#
#    Annual_income  ... ProjectCompletion WorkingFromHome  \
# 0             14  ...                 9              No
# 1             13  ...                14             Yes
# 2              9  ...                12              No
# 3              9  ...                12             Yes
# 4             22  ...                 9             Yes
#
#    Psycho_social_indicators  Over_time Attendance PercentSalaryHike  \
# 0                Inadequate         No       good                 8
# 1                Inadequate         No       good                 3
# 2                 excellent        Yes       good                 3
# 3                 excellent        Yes       good                13
# 4                Inadequate        Yes       good                 7
#
#   NetConnectivity Department        Position Performancerating
# 0            Poor         RD       Scientist           average
# 1            good    Finance  Budget Analyst              good
# 2            Poor         IT     Team leader              good
# 3            good    Finance  Budget Analyst              good
# 4            good         RD       Scientist           average
#
# [5 rows x 28 columns]

# %%
#To view last five data
df.tail()
# Out:
#      ï»¿Employee_ID  Age  Gender Marital_status   Education  \
# 5095         EM6095   70    Male         single      Master
# 5096         EM6096   68  Female       divorced  Vocational
# 5097         EM6097   69  Female        married      Master
# 5098         EM6098   45    Male        married  Vocational
# 5099         EM6099   60    Male       divorced    Bachelor
#
#      EnvironmentSatisfaction JobInvolvement  Job_level Job_satisfaction  \
# 5095                    high      very high          3              low
# 5096                    high           high          4           Medium
# 5097                     low      very high          4             high
# 5098                    high           high          1        very high
# 5099                    high      very high          1              low
#
#       Annual_income  ... ProjectCompletion WorkingFromHome  \
# 5095             11  ...                 9             Yes
# 5096             11  ...                14             Yes
# 5097             23  ...                 9             Yes
# 5098             19  ...                14             Yes
# 5099             20  ...                 5              No
#
#       Psycho_social_indicators  Over_time Attendance PercentSalaryHike  \
# 5095                 Very_good        Yes       good                16
# 5096                Inadequate         No       good                 7
# 5097              satisfactory         No       poor                 9
# 5098              satisfactory         No       good                 3
# 5099                 Very_good         No       poor                 7
#
#      NetConnectivity Department        Position Performancerating
# 5095            good      Sales       Executive              poor
# 5096            good        HRM              HR              poor
# 5097            Poor         RD       Scientist              poor
# 5098            good    Finance  Budget Analyst              poor
# 5099            good         IT     Team leader           average
#
# [5 rows x 28 columns]

# %%
#To view the categorical and numerical columns and its datatypes in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿Employee_ID            5100 non-null   object
#  1   Age                       5100 non-null   int64
#  2   Gender                    5100 non-null   object
#  3   Marital_status            5100 non-null   object
#  4   Education                 5100 non-null   object
#  5   EnvironmentSatisfaction   5100 non-null   object
#  6   JobInvolvement            5100 non-null   object
#  7   Job_level                 5100 non-null   int64
#  8   Job_satisfaction          5100 non-null   object
#  9   Annual_income             5100 non-null   int64
#  10  RelationshipSatisfaction  5100 non-null   object
#  11  Working_hrs_per_Day       5100 non-null   object
#  12  Experience                5100 non-null   int64
#  13  Trainingtime              5100 non-null   int64
#  14  WorkLifeBalance           5100 non-null   object
#  15  BehaviouralCompetence     5100 non-null   object
#  16  On_timeDelivery           5100 non-null   object
#  17  TicketSolvingManagements  5100 non-null   object
#  18  ProjectCompletion         5100 non-null   int64
#  19  WorkingFromHome           5100 non-null   object
#  20  Psycho_social_indicators  5100 non-null   object
#  21  Over_time                 5100 non-null   object
#  22  Attendance                5100 non-null   object
#  23  PercentSalaryHike         5100 non-null   int64
#  24  NetConnectivity           5100 non-null   object
#  25  Department                5100 non-null   object
#  26  Position                  5100 non-null   object
#  27  Performancerating         5100 non-null   object
# dtypes: int64(7), object(21)
# memory usage: 1.1+ MB

# %%
#To check the size of the data

df.shape
# Out:
# (5100, 28)

# %%
#To see the column name 
df.columns

#To find the statistical property of data
df.describe() 
# describe statistics and shape of the data distribution
# Out:
#                Age    Job_level  Annual_income   Experience  Trainingtime  \
# count  5100.000000  5100.000000    5100.000000  5100.000000   5100.000000
# mean     43.890980     2.980392      15.186471    14.108824      3.503529
# std      10.495803     1.408380       6.078839     6.616977      1.693344
# min       5.000000     1.000000       5.000000     0.000000      1.000000
# 25%      35.750000     2.000000      10.000000     9.000000      2.000000
# 50%      43.000000     3.000000      15.000000    16.000000      4.000000
# 75%      52.000000     4.000000      21.000000    20.000000      5.000000
# max      98.000000     5.000000      25.000000    76.000000      6.000000
#
#        ProjectCompletion  PercentSalaryHike
# count        5100.000000        5100.000000
# mean           10.067255           8.501765
# std             3.354400           4.559880
# min             4.000000           1.000000
# 25%             9.000000           5.000000
# 50%            12.000000           8.000000
# 75%            14.000000          12.000000
# max            14.000000          16.000000

# %% [markdown]
# # Auto EDA
# DTALE an automated Library

# %%
! pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\lenovo\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: strsimpy in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: future>=0.14.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: kaleido in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: scikit-learn==0.24.2 in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.24.2)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: lz4 in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (4.0.0)
# Requirement already satisfied: matplotlib in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (3.4.3)
# Requirement already satisfied: flask-ngrok in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: dash-bootstrap-components in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: dash>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2.3.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (5.7.0)
# Requirement already satisfied: dash-colorscales in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: seaborn in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.11.2)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.4.1)
# Requirement already satisfied: squarify in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: itsdangerous in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: statsmodels in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.12.2)
# Requirement already satisfied: openpyxl in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (3.0.9)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.7.1)
# Requirement already satisfied: Flask in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2.1.1)
# Requirement already satisfied: dash-daq in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: cycler in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (0.10.0)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.21.6)
# Requirement already satisfied: ppscore in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.2.0)
# Requirement already satisfied: xlrd in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2.26.0)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2.5.1)
# Requirement already satisfied: xarray in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (2022.3.0)
# Requirement already satisfied: et-xmlfile in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: Flask-Compress in c:\users\lenovo\anaconda3\lib\site-packages (from dtale) (1.11)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn==0.24.2->dtale) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn==0.24.2->dtale) (2.2.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dash>=2.0.0->dtale) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from Flask->dtale) (4.8.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from Flask->dtale) (2.0.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from Flask->dtale) (3.1.1)
# Requirement already satisfied: click>=8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from Flask->dtale) (8.0.3)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from click>=8.0->Flask->dtale) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->Flask->dtale) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask->dtale) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Requirement already satisfied: brotli in c:\users\lenovo\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtale) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtale) (8.4.0)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from networkx->dtale) (4.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->dtale) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->dtale) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->dtale) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->dtale) (1.26.7)
# Requirement already satisfied: patsy>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from statsmodels->dtale) (0.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from xarray->dtale) (21.0)

# %%
import dtale
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-33560840fdc5> in <module>()
# ----> 1 import dtale
#
# ModuleNotFoundError: No module named 'dtale'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
d = dtale.show(df)

# %%
d.open_browser()

# %%
df.columns

# %% [markdown]
# # Data Preprocessing

# %%
# Data Cleaning

#Dropping the columns not necessary for analysis
df=df.drop('ï»¿Employee_ID',axis=1)

# %%
# checking any null values
df.isnull().sum()

# %%
#To check imbalance 
fig = plt.figure(figsize =(10, 7))
plt.pie(df.Performancerating.value_counts(), labels = ['good', 'average', 'poor'], autopct='%1.f%%', pctdistance=0.5)
plt.title('Performance rating of employees')
plt.show()

# %%
df['Performancerating'].value_counts() #3 good, average, poor - 3 classes in taget feature

# the data is balanced dataset.

# %%
import seaborn as sns
#Visualizing the Missing values
sns.heatmap(df.isnull(),cbar=False,cmap='viridis') 

# observations : 
 # no missing data found

# %%
#boxplot - checking presence of outliers

f, ax = plt.subplots(2,4, figsize = (15,7))
plt.suptitle('Boxplot of numerical features')
sns.boxplot(x = df.Age, ax = ax[0][0])
sns.boxplot(x = df.Job_level, ax = ax[0][1])
sns.boxplot(x = df.Annual_income, ax = ax[0][2])
sns.boxplot(x = df.Experience, ax = ax[0][3])
sns.boxplot(x = df.Trainingtime, ax = ax[1][0])
sns.boxplot(x = df.ProjectCompletion, ax = ax[1][1])
sns.boxplot(x = df.PercentSalaryHike, ax = ax[1][2])
f.delaxes(ax[1,3])

# %%
# age and experience features have outliers 

#apply winsorization techniques to handle outliers

from feature_engine.outliers import Winsorizer
gaussian_winsor = Winsorizer(capping_method='gaussian', tail='both', fold=3)
iqr_winsor = Winsorizer(capping_method='iqr', tail='both',fold=1)
quantiles_winsor = Winsorizer(capping_method='quantiles', tail='both', fold=0.10)

# %%
#handling outliers
df[['Age']] = iqr_winsor.fit_transform(df[['Age']])
df[['Experience']] = iqr_winsor.fit_transform(df[['Experience']])

# age & experience features have been winsorized using 'iqr' method.

# %%
# boxplot for checking outliers after winsorization
sns.boxplot(df.Age)

# %%
sns.boxplot(df.Experience)

# %%
#checking duplicates 
duplicates=df.duplicated()
duplicates
sum(duplicates)

#Observations : no duplicated found in data

# %%
# label Encoding
#  objects(categoricals) into numeric - Label Encoding

from sklearn.preprocessing import LabelEncoder
categories = ['Gender', 'Marital_status', 'Education',
       'EnvironmentSatisfaction', 'JobInvolvement',
       'Job_satisfaction', 'RelationshipSatisfaction',
       'Working_hrs_per_Day', 'WorkLifeBalance',
       'BehaviouralCompetence', 'On_timeDelivery', 'TicketSolvingManagements',
       'WorkingFromHome', 'Psycho_social_indicators',
       'Over_time', 'Attendance', 'NetConnectivity',
       'Department', 'Position', 'Performancerating']

# %%
# Encode Categorical Columns
le = LabelEncoder()
df[categories] = df[categories].apply(le.fit_transform)
df

# %% [markdown]
# #   Data Visualisation or Manual EDA (Exploratory Data Analysis)
#  --------------------------------

# %%
 
# Descrptive Analytics
# # Measure of central tendancy - 1st moment business decision 

df.mean()

# Observation: 1) average age of employee is 43.83
        #      2) average salary of employee is 15.18 in lakhs
        #      3) average experience of employee is 14.08 yrs
        #      4) average training time is 3.5 months
        #      5) average no.of projects completed is 10
        #      6) average salary hike of employee in percentages is 8.5
# Out:
# Age                         43.837304
# Gender                       0.498235
# Marital_status               1.009020
# Education                    1.519804
# EnvironmentSatisfaction      1.501373
# JobInvolvement               1.479608
# Job_level                    2.980392
# Job_satisfaction             1.505882
# Annual_income               15.186471
# RelationshipSatisfaction     1.490392
# Working_hrs_per_Day          0.987255
# Experience                  14.080980
# Trainingtime                 3.503529
# WorkLifeBalance              1.514902
# BehaviouralCompetence        1.979804
# On_timeDelivery              1.488627
# TicketSolvingManagements     1.521373
# ProjectCompletion           10.067255
# WorkingFromHome              0.501373
# Psycho_social_indicators     1.983922
# Over_time                    0.325686
# Attendance                   0.330784
# PercentSalaryHike            8.501765
# NetConnectivity              0.503725
# Department                   2.022157
# Position                     2.888431
# Performancerating            0.982549
# dtype: float64

# %%
df.median()
# Observation:  1. average age of employee is 43
        #       2. average annual income of employee is 15 lakhs
        #       3. average work experience of employee is 16
        #       4. average training time is 4 months
        #       5. average no.of. projects completed is 12
        #       6. avereage percent salary hike is 8
        #       7. average job level is 3

 #    # Observation: Mean and median values are not same due to outliers in the dataset.
# Out:
# Age                         43.0
# Gender                       0.0
# Marital_status               1.0
# Education                    2.0
# EnvironmentSatisfaction      2.0
# JobInvolvement               1.0
# Job_level                    3.0
# Job_satisfaction             2.0
# Annual_income               15.0
# RelationshipSatisfaction     1.0
# Working_hrs_per_Day          1.0
# Experience                  16.0
# Trainingtime                 4.0
# WorkLifeBalance              1.0
# BehaviouralCompetence        2.0
# On_timeDelivery              1.0
# TicketSolvingManagements     2.0
# ProjectCompletion           12.0
# WorkingFromHome              1.0
# Psycho_social_indicators     2.0
# Over_time                    0.0
# Attendance                   0.0
# PercentSalaryHike            8.0
# NetConnectivity              1.0
# Department                   2.0
# Position                     3.0
# Performancerating            1.0
# dtype: float64

# %%
   
#Finding mode for categorical data (most frequent)
df[["Gender","Marital_status","EnvironmentSatisfaction","Over_time"]].mode()


# most occuring value..
# gender - female, marital status - single, environment satisfaction- medium, overtime-no
# Out:
#    Gender  Marital_status  EnvironmentSatisfaction  Over_time
# 0       0               2                        2          0

# %%
# # measure of dispersion
df.var() # 2nd moment business decision -var(), std()

# variance - The variance measures the average degree to which each point differs from the mean.


# Variance Observation : age - 105.17
             
             #  annual income - 36.95
             # work experience - 41.9
             # training time  - 2.86
             # project evaluation - 11.25
             # percent salary hike - 20.79
# Out:
# Age                         106.044286
# Gender                        0.250046
# Marital_status                0.670638
# Education                     1.259266
# EnvironmentSatisfaction       1.233377
# JobInvolvement                1.252967
# Job_level                     1.983534
# Job_satisfaction              1.251779
# Annual_income                36.952278
# RelationshipSatisfaction      1.261920
# Working_hrs_per_Day           0.674284
# Experience                   41.990499
# Trainingtime                  2.867413
# WorkLifeBalance               1.246493
# BehaviouralCompetence         1.989982
# On_timeDelivery               1.259922
# TicketSolvingManagements      1.245866
# ProjectCompletion            11.251997
# WorkingFromHome               0.250047
# Psycho_social_indicators      2.013470
# Over_time                     0.219658
# Attendance                    0.221409
# PercentSalaryHike            20.792505
# NetConnectivity               0.250035
# Department                    2.021670
# Position                      4.038737
# Performancerating             0.500774
# dtype: float64

# %%
df.std() # standard deviation - Standard deviation is the spread of a group of numbers from the mean.

# Standard Deviation Observation: 
     #  age  10.25
     # anual income - 6
     
     # work experience - 6.48
     # training time - 1.69
     # project evaluation -  3.35
     # percent salary hike 4.5
     
  # Note: While standard deviation is the square root of the variance, variance is the average of all data points within a group.
# Out:
# Age                         10.297781
# Gender                       0.500046
# Marital_status               0.818925
# Education                    1.122170
# EnvironmentSatisfaction      1.110575
# JobInvolvement               1.119360
# Job_level                    1.408380
# Job_satisfaction             1.118830
# Annual_income                6.078839
# RelationshipSatisfaction     1.123352
# Working_hrs_per_Day          0.821148
# Experience                   6.480008
# Trainingtime                 1.693344
# WorkLifeBalance              1.116464
# BehaviouralCompetence        1.410667
# On_timeDelivery              1.122462
# TicketSolvingManagements     1.116184
# ProjectCompletion            3.354400
# WorkingFromHome              0.500047
# Psycho_social_indicators     1.418968
# Over_time                    0.468677
# Attendance                   0.470542
# PercentSalaryHike            4.559880
# NetConnectivity              0.500035
# Department                   1.421854
# Position                     2.009661
# Performancerating            0.707654
# dtype: float64

# %%
range = max(df.Age)-min(df.Age)
range #48.75
# Out:
# 48.75

# %%
# # measure of skewess and kurtosis - 3rd & 4th business moment decisions

df.skew() #3rd moment business decision - skewness - a long tail
# Skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data. If the curve is shifted to the left or to the right, it is said to be skewed

# Observations:
    # age 0.17 psitively or right skewed
    # joblevel   0.025 - positively or right skewed
    # annual income -0.05 - positively or right skewed
    # work experience -0.58 negatively or left skewed
    # training time  -0.0040  - negatively or left skewed
    # project evaluation   -0.37 - negatively or left skewed
    # percent salary hike  0.01  - positively or right skewed
# Out:
# Age                         0.156153
# Gender                      0.007061
# Marital_status             -0.016623
# Education                  -0.031971
# EnvironmentSatisfaction    -0.005607
# JobInvolvement              0.045168
# Job_level                   0.025914
# Job_satisfaction           -0.019772
# Annual_income              -0.053104
# RelationshipSatisfaction    0.011518
# Working_hrs_per_Day         0.023553
# Experience                 -0.588502
# Trainingtime               -0.004013
# WorkLifeBalance            -0.003124
# BehaviouralCompetence       0.035771
# On_timeDelivery             0.027148
# TicketSolvingManagements   -0.036699
# ProjectCompletion          -0.373307
# WorkingFromHome            -0.005492
# Psycho_social_indicators    0.002008
# Over_time                   0.744147
# Attendance                  0.719520
# PercentSalaryHike           0.015958
# NetConnectivity            -0.014907
# Department                 -0.012031
# Position                   -0.066550
# Performancerating           0.024752
# dtype: float64

# %%
df.kurt() # 4th moment business decision- measure of tailedness of probability distribution
# Kurtosis is defined as the standardized fourth central moment of a distribution minus 3 (to make the kurtosis of the normal distribution equal to zero).
# standard normal distribution has kurtosis of 3 (Mesokurtic), 
# kurtosis >3 is  - leptokurtic, <3 is platykurtic

   # Observations:
       # age  is    -0.66- platykurtic
       # joblevel    -1.28  - leptokurtic
       # anual income  -1.01- platykurtic
       # work experience  -1.55 platykurtic
       # training time  -1.24 - leptokurtic
       # project evaluation   -1.25 - platykurtic
       # percent salary hike  -1.18 - platykurtic
# Out:
# Age                        -0.683869
# Gender                     -2.000735
# Marital_status             -1.508708
# Education                  -1.368347
# EnvironmentSatisfaction    -1.342680
# JobInvolvement             -1.360979
# Job_level                  -1.289933
# Job_satisfaction           -1.361423
# Annual_income              -1.218000
# RelationshipSatisfaction   -1.371941
# Working_hrs_per_Day        -1.516590
# Experience                 -1.017738
# Trainingtime               -1.245965
# WorkLifeBalance            -1.356849
# BehaviouralCompetence      -1.294668
# On_timeDelivery            -1.369330
# TicketSolvingManagements   -1.354311
# ProjectCompletion          -1.253381
# WorkingFromHome            -2.000755
# Psycho_social_indicators   -1.311381
# Over_time                  -1.446813
# Attendance                 -1.482873
# PercentSalaryHike          -1.181914
# NetConnectivity            -2.000562
# Department                 -1.311505
# Position                   -1.262767
# Performancerating          -1.002500
# dtype: float64

# %%
#Fifth moment business decision - Graphical representation

# Univariate analysis
# --------------------------------------------------

# histogram
df.hist() # overall distribution of data
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'Marital_status'}>,
#         <AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'EnvironmentSatisfaction'}>],
#        [<AxesSubplot:title={'center':'JobInvolvement'}>,
#         <AxesSubplot:title={'center':'Job_level'}>,
#         <AxesSubplot:title={'center':'Job_satisfaction'}>,
#         <AxesSubplot:title={'center':'Annual_income'}>,
#         <AxesSubplot:title={'center':'RelationshipSatisfaction'}>],
#        [<AxesSubplot:title={'center':'Working_hrs_per_Day'}>,
#         <AxesSubplot:title={'center':'Experience'}>,
#         <AxesSubplot:title={'center':'Trainingtime'}>,
#         <AxesSubplot:title={'center':'WorkLifeBalance'}>,
#         <AxesSubplot:title={'center':'BehaviouralCompetence'}>],
#        [<AxesSubplot:title={'center':'On_timeDelivery'}>,
#         <AxesSubplot:title={'center':'TicketSolvingManagements'}>,
#         <AxesSubplot:title={'center':'ProjectCompletion'}>,
#         <AxesSubplot:title={'center':'WorkingFromHome'}>,
#         <AxesSubplot:title={'center':'Psycho_social_indicators'}>],
#        [<AxesSubplot:title={'center':'Over_time'}>,
#         <AxesSubplot:title={'center':'Attendance'}>,
#         <AxesSubplot:title={'center':'PercentSalaryHike'}>,
#         <AxesSubplot:title={'center':'NetConnectivity'}>,
#         <AxesSubplot:title={'center':'Department'}>],
#        [<AxesSubplot:title={'center':'Position'}>,
#         <AxesSubplot:title={'center':'Performancerating'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
sns.histplot(data=df, x='Age', kde=True)
# observation: 
    # age is slightly skewed. (right skewed)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x='Annual_income', kde=True)
# observation:
    # salary is uniformly distributed.
# Out:
# <AxesSubplot:xlabel='Annual_income', ylabel='Count'>

# %%
sns.histplot(data=df, x='Experience', kde=True)
# observations:
    # experience feature is  left skewed.
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Count'>

# %%
sns.histplot(data=df, x='Trainingtime', kde=True)
# observations:
    # training time - data is uniformly distributed.
# Out:
# <AxesSubplot:xlabel='Trainingtime', ylabel='Count'>

# %%
sns.countplot(x='Performancerating', hue="Gender", data=df)
# observations : 
    # Female employees performance is good than male employees performance.
# Out:
# <AxesSubplot:xlabel='Performancerating', ylabel='count'>

# %%
sns.countplot(x='Performancerating', hue="WorkingFromHome", data=df)
# observation:
    # both work form home & working from office employees performance is almost similar.
# Out:
# <AxesSubplot:xlabel='Performancerating', ylabel='count'>

# %%
sns.countplot(y='Department', hue="Performancerating", data=df)

# observation:
    # employees in Finance & HR departments performing similiar in performance.
# Out:
# <AxesSubplot:xlabel='count', ylabel='Department'>
# Executing shutdown due to inactivity...
# 2022-06-11 22:30:39,157 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-06-11 22:30:43,321 - INFO     - Executing shutdown...

# %%
sns.countplot(y='Position', hue="Performancerating", data=df)
# observation:
    # budget analyst & hr positions performing good, managers are performing poor.
# Out:
# <AxesSubplot:xlabel='count', ylabel='Position'>

# %%
sns.countplot(y='Department', hue="EnvironmentSatisfaction", data=df)
# observation:
    # R&D department employees are very highly satisfied with environment & IT deaprtment employees are low satisfied.
# Out:
# <AxesSubplot:xlabel='count', ylabel='Department'>

# %%
sns.countplot(x='Job_satisfaction', hue="WorkingFromHome", data=df)
# observation:
    # most employees working from home are not satisfied with their job.
# Out:
# <AxesSubplot:xlabel='Job_satisfaction', ylabel='count'>

# %%
sns.countplot(x='EnvironmentSatisfaction', hue="WorkingFromHome", data=df)
# observation:
    # most emplpoyees working from home are satisfied with the environment.
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
sns.countplot(x='JobInvolvement', hue="WorkingFromHome", data=df)
# observation:
    # employees working from home are highly involved in job.
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %%
sns.countplot(x='RelationshipSatisfaction', hue="Gender", data=df)
# observation:
    # Male employees are satisfied with relationship
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %%
sns.countplot(y='Position', hue="BehaviouralCompetence", data=df)
# observation:
    # scientist having excellent behaviourial competence & recruiters have low in behaviourial competence.
# Out:
# <AxesSubplot:xlabel='count', ylabel='Position'>

# %%
sns.countplot(x='WorkLifeBalance', hue="Gender", data=df)
# observation:
    #most of Male employees have best work life balance.
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %%
sns.countplot(x='Marital_status', hue="On_timeDelivery", data=df)
# observation:
    # single employees are excellent in delivering projects.
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(x='TicketSolvingManagements', hue="Gender", data=df)
# observation:
    # male employees are excellent in ticket solving management.
# Out:
# <AxesSubplot:xlabel='TicketSolvingManagements', ylabel='count'>

# %%
sns.countplot(y='Department', hue="TicketSolvingManagements", data=df)
# observation:
    # HRM department is excellent in ticket solving management & finance department is poor in ticket solving management.
# Out:
# <AxesSubplot:xlabel='count', ylabel='Department'>

# %%
sns.countplot(x='Performancerating', hue="NetConnectivity", data=df)
# observation:
    # employees with good internet connection have good performance & We can see that the issue of bad net connection leads to low performance"""
# Out:
# <AxesSubplot:xlabel='Performancerating', ylabel='count'>

# %%
sns.countplot(x='Over_time', hue="NetConnectivity", data=df)
# We can see that the issue of bad net connection leads to over time.
# Out:
# <AxesSubplot:xlabel='Over_time', ylabel='count'>

# %%
sns.countplot(x='WorkingFromHome', data=df)
# employees working from home are slight more than work from office employees
# Out:
# <AxesSubplot:xlabel='WorkingFromHome', ylabel='count'>

# %%
#---> Bivarirate analysis

#bar plot - categorical vs numerical features

sns.barplot(x = df.Performancerating, y = df.Experience)
# observation:
    #  employees with more experience performance is good.
# Out:
# <AxesSubplot:xlabel='Performancerating', ylabel='Experience'>

# %%
sns.barplot(x = df.Performancerating, y = df.Age)
 #aged employees performing well.
# Out:
# <AxesSubplot:xlabel='Performancerating', ylabel='Age'>

# %%
sns.barplot(x = df.ProjectCompletion, y = df.Age)
# employees who complted more projects in the ages 40-45.
# Out:
# <AxesSubplot:xlabel='ProjectCompletion', ylabel='Age'>

# %%
sns.barplot(x = df.Gender, y = df.PercentSalaryHike)
    # observation:
    # male employees have got bit more hike than female employees.
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='PercentSalaryHike'>

# %%
sns.barplot(x = df.Education, y = df.Annual_income)
# employeess with vocational qualification getting high salaries than others.
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Annual_income'>

# %%
#correlation matrix

corr = df.corr()
corr
# Correlation between different variables
corr = df.corr()
# Set up the matplotlib plot configuration
f, ax = plt.subplots(figsize=(30, 10))
# Generate a mask for upper traingle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Configure a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
# Generate a mask for upper traingle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Configure a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital_status', 'Education',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'Job_level',
#        'Job_satisfaction', 'Annual_income', 'RelationshipSatisfaction',
#        'Working_hrs_per_Day', 'Experience', 'Trainingtime', 'WorkLifeBalance',
#        'BehaviouralCompetence', 'On_timeDelivery', 'TicketSolvingManagements',
#        'ProjectCompletion', 'WorkingFromHome', 'Psycho_social_indicators',
#        'Over_time', 'Attendance', 'PercentSalaryHike', 'NetConnectivity',
#        'Department', 'Position', 'Performancerating'],
#       dtype='object')

# %%
#Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import accuracy_score,confusion_matrix

#separating dependent and independent columns 
X = df.iloc[:,0:26]  #independent columns
y = df.iloc[:,-1]    #target column

# %%
# feature scaling

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df.iloc[:, 0:26]))
df[df.columns[0:26]] = df_scaled[df_scaled.columns[0:26]]

# %% [markdown]
# # Data Modelling

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=30) # 70% training and 30% test

     
# Model building for Decision Tree

clf = DecisionTreeClassifier(criterion="gini", max_depth=3)

clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# predicing for train and test
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

# %%
# accuracy of train 

print(f'Train score {accuracy_score(y_train_pred,y_train)}') # 98.5
# Out:
# Train score 0.9854341736694678

# %%
# accuracy of test
print(f'Test score {accuracy_score(y_test_pred,y_test)}')  #  98.3
# Out:
# Test score 0.9830065359477124

# %%
# confusion matrix for performance metrics
cm = confusion_matrix(y_test, y_test_pred)
cm
# or
pd.crosstab(y_test, y_test_pred, rownames=['Actual'], colnames=['Predictions'])
# Out:
# Predictions    0    1    2
# Actual
# 0            381    2    9
# 1              2  760    9
# 2              2    2  363

# %%
# Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       392
#            1       0.99      0.99      0.99       771
#            2       0.95      0.99      0.97       367
#
#     accuracy                           0.98      1530
#    macro avg       0.98      0.98      0.98      1530
# weighted avg       0.98      0.98      0.98      1530

# %%
# roc_auc_score

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

preds = clf.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test,  preds, pos_label=1)

roc_auc_score(y, clf.predict_proba(X), multi_class='ovr') #99.9
# Out:
# 0.9996569382674373

# %%
# probability collaboration curve

fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], color='navy', linestyle='--', label='random')
plt.title(f'AUC: {roc_auc_score}')
ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
# Out:
# Text(0, 0.5, 'True positive rate')
# 2022-06-12 16:59:27,068 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# 2022-06-12 16:59:27,087 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.

# %%
# Random Forest classifier

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=10) 
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
#predictions 
y_train_predict = rfc.predict(X_train)
y_test_predict = rfc.predict(X_test)

# %%
# accuracy score for training data
print(f'Train score {accuracy_score(y_train_predict, y_train)}') # 99.8 %
# Out:
# Train score 0.9980392156862745

# %%
# accuracy score for test data
print(f'Test score {accuracy_score(y_test_predict, y_test)}')  #  98.4 %
# Out:
# Test score 0.984313725490196

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_test_predict)
cm

pd.crosstab(y_test, y_test_predict, rownames=['Actual'], colnames=['Predictions'])
# Out:
# Predictions    0    1    2
# Actual
# 0            381    9    2
# 1              1  769    1
# 2              2    9  356

# %%
# Classification Report
print(classification_report(y_test, y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       392
#            1       0.98      1.00      0.99       771
#            2       0.99      0.97      0.98       367
#
#     accuracy                           0.98      1530
#    macro avg       0.99      0.98      0.98      1530
# weighted avg       0.98      0.98      0.98      1530

# %%
# XGBoost Classifier
from xgboost import XGBClassifier

xgb = XGBClassifier(n_estimators=100)

xgb.fit(X_train, y_train)
# Out:
# [17:16:21] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
# prediction for train and test data

predict_train = xgb.predict(X_train)
predict_test = xgb.predict(X_test)

# %%
# accuracy score for train data

print(f'Train score {accuracy_score(predict_train, y_train)}') #  1.0 -> overfitting
# Out:
# Train score 1.0

# %%
# accuracy score for test data

print(f'Test score {accuracy_score(predict_test, y_test)}')  #  98.0 %
# Out:
# Test score 0.9803921568627451

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, predict_test)
cm
pd.crosstab(y_test, predict_test, rownames=['Actual'], colnames=['Predictions'])
# Out:
# Predictions    0    1    2
# Actual
# 0            379    9    4
# 1              2  763    6
# 2              2    7  358

# %%
# Classification Report
print(classification_report(y_test, predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       392
#            1       0.98      0.99      0.98       771
#            2       0.97      0.98      0.97       367
#
#     accuracy                           0.98      1530
#    macro avg       0.98      0.98      0.98      1530
# weighted avg       0.98      0.98      0.98      1530

# %%
#  KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier().fit(X_train, y_train)

# %%
 
#Predict the response for test dataset
y_pred=knn.predict(X_test)

# %%
# Model Accuracy for train data
print("Accuracy:",metrics.accuracy_score(y_train,knn.predict(X_train) )) # 96%
# Out:
# Accuracy: 0.9672268907563025

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))   
 # test accuracy is 92%
# Out:
# Accuracy: 0.9235294117647059

# %%
# creating a confusion matrix
knn_predictions = knn.predict(X_test)
cm = confusion_matrix(y_test, knn_predictions)
cm
pd.crosstab(y_test, knn_predictions, rownames=['Actual'], colnames=['Predictions'])
# Out:
# Predictions    0    1    2
# Actual
# 0            333   52    7
# 1             25  746    0
# 2             23   10  334

# %%
# Classification Report
print(classification_report(y_test, knn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       392
#            1       0.92      0.97      0.94       771
#            2       0.98      0.91      0.94       367
#
#     accuracy                           0.92      1530
#    macro avg       0.93      0.91      0.92      1530
# weighted avg       0.92      0.92      0.92      1530

# %%
# MultiNomial Naivebayes

from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
predictions = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_train,clf.predict(X_train) ))
# train  Accuracy is 85
# Out:
# Accuracy: 0.8599439775910365

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# test accuracy is 86
# Out:
# Accuracy: 0.8601307189542484

# %%
# creating a confusion matrix
knn_predictions = knn.predict(X_test)
cm = confusion_matrix(y_test, knn_predictions)
cm
pd.crosstab(y_test, knn_predictions, rownames=['Actual'], colnames=['Predictions'])
# Out:
# Predictions    0    1    2
# Actual
# 0            333   52    7
# 1             25  746    0
# 2             23   10  334

# %%
# Classification Report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.51      0.66       392
#            1       0.79      0.99      0.88       771
#            2       0.99      0.96      0.97       367
#
#     accuracy                           0.86      1530
#    macro avg       0.91      0.82      0.84      1530
# weighted avg       0.88      0.86      0.85      1530
#
# Executing shutdown due to inactivity...
# 2022-06-12 17:46:07,468 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-06-12 17:46:11,728 - INFO     - Executing shutdown...

# %%
# Out of 5 models  Decision Tree  is performing best  98% accuracy and F1 Score.
